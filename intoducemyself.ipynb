# %%
print("Hello, My name is Phanuth HUN u can call me Steven")
print("I am 20 years old")
print("I am studying at CUS in Computer Science major and and currently pursuing Air Traffic Management")
print("My hobbies are playing football, playing video games, and traveling")
# Out:
# Hello, My name is Phanuth HUN u can call me Steven
# I am 20 years old
# I am studying at CUS in Computer Science major and and currently pursuing Air Traffic Management
# My hobbies are playing football, playing video games, and traveling

# %%
# This is a single-line comment
print("Hello, world!") # This is an inline comment
# Out:
# Hello, world!

# %%
"""
This is a multiline string.
It can be used as a comment if not assigned to a variable.
"""
def example_function():
    pass

# %%
print(123)
print(2.2)
# Out:
# 123
# 2.2

# %%
print(2+2-1+3)
# Out:
# 6

# %%
print("A"*3)
# Out:
# AAA

# %%
print("Hello, World!")
name = "Steven"*5
print(name)

age = 20
print("Name:", name, "Age:", age)
# Out:
# Hello, World!
# StevenStevenStevenStevenSteven
# Name: StevenStevenStevenStevenSteven Age: 20

# %%
print('Hello',"world", sep=",")
# Out:
# Hello,world

# %%
a=10; a+=10; print(a)
# Out:
# 20

# %%
a=10
a+=10
print(10)
