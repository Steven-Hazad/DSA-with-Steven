# %%
print("Hello, World")
print(3.14)
print(True)
print("2026", "02", "06", sep="-")
print("Line 1\nLine 2\nLine 3")
print("Name\tAge\tCountry")
print("Steven\t20\tCambodia")
# Out:
# Hello, World
# 3.14
# True
# 2026-02-06
# Line 1
# Line 2
# Line 3
# Name	Age	Country
# Steven	20	Cambodia

# %%
name = "Steven"
age = 20
print(name, age)

# %%
a = 5
b = 3
print(f"Sum = {a + b}")

# %%
name = "Steven"
age = 20
print("My name is {} and I am {} years old".format(name, age))
# Out:
# My name is Steven and I am 20 years old

# %%
print("He said \"Hello\"")
print('It\'s Python')
# Out:
# He said "Hello"
# It's Python

# %%
# This is a comment
print("Hello")  # This is also a comment

# %%
def main():
    """
    This is the main function
    It prints a message
    """
    print("Hello from main")

main()
